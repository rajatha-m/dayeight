# %% [markdown]
# ### Clusteing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
#create data
data=make_blobs(n_samples=200,n_features=2,centers=4,cluster_std=1.8,random_state=101)
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans(n_clusters=4)
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[-0.0123077 ,  2.13407664],
#        [-4.13591321,  7.95389851],
#        [-9.46941837, -6.56081545],
#        [ 3.71749226,  7.01388735]])

# %%
kmeans.labels_
# Out:
# array([1, 3, 0, 3, 3, 2, 3, 0, 3, 0, 1, 0, 3, 3, 1, 0, 3, 0, 2, 1, 2, 0,
#        0, 2, 1, 2, 2, 0, 3, 3, 1, 2, 3, 0, 0, 1, 2, 2, 2, 0, 2, 1, 1, 1,
#        0, 3, 1, 0, 2, 0, 0, 1, 3, 0, 2, 1, 0, 0, 1, 3, 2, 3, 2, 1, 3, 0,
#        2, 3, 3, 2, 3, 0, 2, 0, 2, 3, 3, 0, 1, 0, 0, 2, 3, 2, 0, 0, 0, 1,
#        0, 2, 2, 2, 2, 0, 0, 2, 3, 1, 2, 3, 0, 2, 0, 0, 3, 0, 2, 3, 2, 2,
#        3, 1, 1, 3, 2, 3, 1, 1, 3, 1, 0, 1, 0, 1, 0, 3, 1, 0, 2, 1, 1, 1,
#        0, 2, 2, 1, 3, 1, 3, 0, 2, 3, 2, 1, 1, 3, 0, 2, 1, 1, 1, 1, 0, 3,
#        0, 1, 3, 3, 3, 0, 3, 0, 0, 1, 2, 1, 0, 3, 1, 0, 3, 0, 1, 3, 0, 1,
#        3, 3, 2, 3, 1, 2, 2, 1, 2, 2, 2, 2, 2, 0, 2, 3, 3, 1, 2, 0, 3, 3,
#        2, 0])

# %%
f,(ax1,ax2)=plt.subplots(1,2,sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
coll=pd.read_csv('College_Data')

# %%
coll
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
coll.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
coll.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
# Unnamed: 0     777 non-null object
# Private        777 non-null object
# Apps           777 non-null int64
# Accept         777 non-null int64
# Enroll         777 non-null int64
# Top10perc      777 non-null int64
# Top25perc      777 non-null int64
# F.Undergrad    777 non-null int64
# P.Undergrad    777 non-null int64
# Outstate       777 non-null int64
# Room.Board     777 non-null int64
# Books          777 non-null int64
# Personal       777 non-null int64
# PhD            777 non-null int64
# Terminal       777 non-null int64
# S.F.Ratio      777 non-null float64
# perc.alumni    777 non-null int64
# Expend         777 non-null int64
# Grad.Rate      777 non-null int64
# dtypes: float64(1), int64(16), object(2)
# memory usage: 115.4+ KB

# %%
coll.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
 sns.set_style('whitegrid')
sns.lmplot('Room.Board','Grad.Rate',data=coll,hue='Private',palette='coolwarm',size=6,aspect=1,fit_reg=False)
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
 sns.set_style('whitegrid')
sns.lmplot('Outstate','F.Undergrad',data=coll,hue='Private',palette='coolwarm',size=6,aspect=1,fit_reg=False)
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
sns.set_style('darkgrid')
g=sns.FacetGrid(coll,hue='Private',palette='coolwarm',size=6,aspect=2)
g=g.map(plt.hist,'Outstate',bins=20,alpha=0.7)
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\seaborn\axisgrid.py:230: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
coll['Grad.Rate']['Cazenovia College']=100
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
from sklearn.cluster import KMeans

# %%
coll[coll['Grad.Rate']>100]
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College     Yes  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 95         1010           12      9384        4840    600       500   22
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(coll.drop('Private',axis=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-c342e2e0f505> in <module>
#       1 kmeans=KMeans(n_clusters=2)
# ----> 2 kmeans.fit(coll.drop('Private',axis=1))
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in fit(self, X, y, sample_weight)
#     969                 tol=self.tol, random_state=random_state, copy_x=self.copy_x,
#     970                 n_jobs=self.n_jobs, algorithm=self.algorithm,
# --> 971                 return_n_iter=True)
#     972         return self
#     973
#
# ~\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py in k_means(X, n_clusters, sample_weight, init, precompute_distances, n_init, max_iter, verbose, tol, random_state, copy_x, n_jobs, algorithm, return_n_iter)
#     309     order = "C" if copy_x else None
#     310     X = check_array(X, accept_sparse='csr', dtype=[np.float64, np.float32],
# ...

# %%
 coll[coll['Grad.Rate'] > 100]
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College     Yes  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 95         1010           12      9384        4840    600       500   22
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %%
coll['Grad.Rate']['Cazenovia College'] = 100

# %%
coll.replace(-999, np.nan)
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
coll[coll['Grad.Rate'] > 100]
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#            Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# 95  Cazenovia College     Yes  3847    3433     527          9         35
#
#     F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  PhD  \
# 95         1010           12      9384        4840    600       500   22
#
#     Terminal  S.F.Ratio  perc.alumni  Expend  Grad.Rate
# 95        47       14.3           20    7697        118

# %%
coll.replace(-999, np.nan)
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
coll.replace(118,100)
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
df=pd.read_csv('Classified Data')

# %%
df
# Out:
#      Unnamed: 0       WTT       PTI       EQW       SBI       LQE       QWG  \
# 0             0  0.913917  1.162073  0.567946  0.755464  0.780862  0.352608
# 1             1  0.635632  1.003722  0.535342  0.825645  0.924109  0.648450
# 2             2  0.721360  1.201493  0.921990  0.855595  1.526629  0.720781
# 3             3  1.234204  1.386726  0.653046  0.825624  1.142504  0.875128
# 4             4  1.279491  0.949750  0.627280  0.668976  1.232537  0.703727
# 5             5  0.833928  1.523302  1.104743  1.021139  1.107377  1.010930
# 6             6  0.944705  1.251761  1.074885  0.286473  0.996440  0.428860
# 7             7  0.816174  1.088392  0.895343  0.243860  0.943123  1.045131
# 8             8  0.776551  1.463812  0.783825  0.337278  0.742215  1.072756
# 9             9  0.772280  0.515111  0.891596  0.940862  1.430568  0.885876
# 10           10  1.284999  1.331018  0.618910  0.657017  1.037191  0.717346
# ...

# %%
knn=pd.read_csv('KNN_Project_Data')

# %%
knn
# Out:
#             XVPM         GWYH         TRAT        TLLZ         IGGA  \
# 0    1636.670614   817.988525  2565.995189  358.347163   550.417491
# 1    1013.402760   577.587332  2644.141273  280.428203  1161.873391
# 2    1300.035501   820.518697  2025.854469  525.562292   922.206261
# 3    1059.347542  1066.866418   612.000041  480.827789   419.467495
# 4    1018.340526  1313.679056   950.622661  724.742174   843.065903
# 5    1587.993461   667.420121  2072.048544  364.624958   905.011385
# 6    1497.293624   822.435853   908.059366  671.797517  1280.270442
# 7    1172.820769  1166.958461   455.656588  445.572745  1109.894585
# 8     839.494647  1089.747059   653.699894  659.334590  1529.725972
# 9    1028.689140   202.089774  1030.841860  429.109102   943.104815
# 10   1042.945431   826.009900   741.518594  548.237381  1528.675999
# 11    715.533949   768.001549  1513.342810   95.995876  1281.787242
# 12    747.291672   686.633284  1616.229550  511.187764  1134.462664
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
scaler.fit(df.drop('TARGET CLASS',axis=1))
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
scaled_features=scaler.transform(df.drop('TARGET CLASS',axis=1))
# Out:
# C:\Users\RAJATHA\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   """Entry point for launching an IPython kernel.

# %%
df_feat=pd.DataFrame(scaled_features,columns=df.columns[:-1])
df_feat.head()
# Out:
#    Unnamed: 0       WTT       PTI       EQW       SBI       LQE       QWG  \
# 0   -1.730320 -0.123542  0.185907 -0.913431  0.319629 -1.033637 -2.308375
# 1   -1.726856 -1.084836 -0.430348 -1.025313  0.625388 -0.444847 -1.152706
# 2   -1.723391 -0.788702  0.339318  0.301511  0.755873  2.031693 -0.870156
# 3   -1.719927  0.982841  1.060193 -0.621399  0.625299  0.452820 -0.267220
# 4   -1.716463  1.139275 -0.640392 -0.709819 -0.057175  0.822886 -0.936773
#
#         FDJ       PJF       HQE       NXJ
# 0 -0.798951 -1.482368 -0.949719 -0.643314
# 1 -1.129797 -0.202240 -1.828051  0.636759
# 2  2.599818  0.285707 -0.682494 -0.377850
# 3  1.750208  1.066491  1.241325 -1.026987
# 4  0.596782 -1.472352  1.040772  0.276510

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,x_test,y_train,y_test=train_test_split(scaled_features,df['TARGET CLASS'],test_size=0.30)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn= KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=1, p=2,
#            weights='uniform')

# %%
pred=knn.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[139  21]
#  [ 13 127]]

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       160
#            1       0.86      0.91      0.88       140
#
#    micro avg       0.89      0.89      0.89       300
#    macro avg       0.89      0.89      0.89       300
# weighted avg       0.89      0.89      0.89       300

# %%
error_rate=[]
for i in range(1,40):
    knn= KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i=knn.predict(x_test)
    error_rate.append(np.mean(pred_i!=y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)
plt.title('Error Rate vs. K Value')
plt.xlabel('K')
plt.ylabel('Error Rate')
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn= KNeighborsClassifier(n_neighbors=20)
knn.fit(X_train,y_train)
pred=knn.predict(_test)
print('WITH K=20')
print('\n')
print(confusion_matrix(y_test,pred))
print('\n')
print(classification_report(y_test,pred))
# Out:
# WITH K=20
#
#
# [[146  14]
#  [  7 133]]
#
#
#               precision    recall  f1-score   support
#
#            0       0.95      0.91      0.93       160
#            1       0.90      0.95      0.93       140
#
#    micro avg       0.93      0.93      0.93       300
#    macro avg       0.93      0.93      0.93       300
# weighted avg       0.93      0.93      0.93       300

# %%
import cv2 
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
print("OpenCV-Python Version %s"%cv2.__version__)
# Out:
# OpenCV-Python Version 4.1.0

# %%
 img=cv2.imread('messi.jpg',cv2.IMREAD_COLOR)
#if image path is wrong the resulting img will be null
if img is None:
    print('Open Error')
else:
    print('Image Loaded')
# Out:
# Image Loaded

# %%
print(type(img))
print(img.shape)
print(img.dtype)
print(img[:2, :2, :])
# Out:
# <class 'numpy.ndarray'>
# (342, 548, 3)
# uint8
# [[[39 43 44]
#   [42 46 47]]
#
#  [[37 40 44]
#   [42 45 49]]]

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
import numpy as np
img2=np.zeros((512,512,3),np.uint8)
plt.imshow(img2)

# %%
cv2.line(img2,(0,0),(511,511),(255,0,0),5)
plt.imshow(img2)

# %%
cv2.rectangle(img2,(384,0),(510,128),(0,255,0),3)
plt.imshow(img2)

# %%
cv2.circle(img2,(447,63),63,(0,0,255),-1)
plt.imshow(img2)

# %%
cv2.ellipse(img2,(256,256),(100,50),-45,0,180,(255,0,0),-1)
plt.imshow(img2)

# %%
img[50,235]
# Out:
# array([29, 24, 25], dtype=uint8)

# %%
for i in range(5):
    for j in range(5):
        img[50+i,235+j]=(0,255,0)
        plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
for i in range(5):
    for j in range(5):
        img[255+i,435+j]=(0,300,0)
        plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
ball=img[280:340,330:390]
img[273:333,100:160]=ball
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
stud = img[250:290, 380:460]
img[250:290, 150:230] = stud

stud2 = img[301:333, 251:310]
img[301:333, 162:221] = stud2
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
